# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pickle
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(r'E:\Surendra Data\DATA Scientist Course Detail\Internship\Project Work\1-Phase-Evaluation-Projects\baseball.csv')

data.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
data.shape
# Out:
# (30, 17)

# %%
data.rename(columns = {'2B': 'Double', '3B':'Triple'}, inplace = True)

data.head()
# Out:
#     W    R    AB     H  Double  Triple   HR   BB    SO   SB   RA   ER   ERA  \
# 0  95  724  5575  1497     300      42  139  383   973  104  641  601  3.73
# 1  83  696  5467  1349     277      44  156  439  1264   70  700  653  4.07
# 2  81  669  5439  1395     303      29  141  533  1157   86  640  584  3.67
# 3  76  622  5533  1381     260      27  136  404  1231   68  701  643  3.98
# 4  74  689  5605  1515     289      49  151  455  1259   83  803  746  4.64
#
#    CG  SHO  SV    E
# 0   2    8  56   88
# 1   2   12  45   86
# 2  11   10  38   79
# 3   7    9  37  101
# 4   7   12  35   86

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   Double  30 non-null     int64
#  5   Triple  30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
data.isnull().sum()
# Out:
# W         0
# R         0
# AB        0
# H         0
# Double    0
# Triple    0
# HR        0
# BB        0
# SO        0
# SB        0
# RA        0
# ER        0
# ERA       0
# CG        0
# SHO       0
# SV        0
# E         0
# dtype: int64

# %%
data.describe()
# Out:
#                 W           R           AB            H      Double  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#           Triple          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %%
data_corr = data.corr().abs()

plt.figure(figsize = (22,16))
sns.heatmap(data_corr, annot = True, annot_kws={'size':12})
plt.show()

# %% [markdown]
# Observations:
# - There seems to be strong correlation between RA, ER and ERA variables. We will check the same using VIF.
# - R, ER and ERA having strong relation with Target variable W, we will check the same using Hypothesis Testing and Intercept.
# - AB and H, are having correlation values as 0.74, all other variables are having very less correlation values.

# %% [markdown]
# ## Univariate Analysis

# %%
sns.distplot(data.R)
# Out:
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %%
sns.distplot(data.AB)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Density'>

# %%
sns.distplot(data.H)
# Out:
# <AxesSubplot:xlabel='H', ylabel='Density'>

# %%
sns.distplot(data.Double)
# Out:
# <AxesSubplot:xlabel='Double', ylabel='Density'>

# %%
sns.distplot(data.Triple)
# Out:
# <AxesSubplot:xlabel='Triple', ylabel='Density'>

# %%
sns.distplot(data.HR)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Density'>

# %%
sns.distplot(data.BB)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='Density'>

# %%
sns.distplot(data.SO)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='Density'>

# %%
sns.distplot(data.SB)
# Out:
# <AxesSubplot:xlabel='SB', ylabel='Density'>

# %%
sns.distplot(data.RA)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Density'>

# %%
sns.distplot(data.ER)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='Density'>

# %%
sns.distplot(data.ERA)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='Density'>

# %%
sns.distplot(data.CG)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='Density'>

# %%
sns.distplot(data.SHO)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Density'>

# %%
sns.distplot(data.SV)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Density'>

# %%
sns.distplot(data.E)
# Out:
# <AxesSubplot:xlabel='E', ylabel='Density'>

# %% [markdown]
# There seems to be some skewness in the data, we will check for the same.

# %% [markdown]
# # Bivariate Analysis

# %%
sns.regplot(x='R', y='W', data=data)
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %%
sns.regplot(x='ER', y='W', data=data)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='W'>

# %%
sns.regplot(x='ERA', y='W', data=data)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='W'>

# %% [markdown]
# Both ER and ERA variables are negativly related with the Target variable W, whereas R(Run) is having positive linear relation with Target Variable W.

# %%
sns.regplot(x='R', y='ER', data=data)
# Out:
# <AxesSubplot:xlabel='R', ylabel='ER'>

# %%
sns.regplot(x='R', y='ERA', data=data)
# Out:
# <AxesSubplot:xlabel='R', ylabel='ERA'>

# %%
sns.regplot(x='ER', y='ERA', data=data)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='ERA'>

# %% [markdown]
# It can be clearly seen that R is very weakly realted with ER and ERA, but ER and ERA has a very strongly relation amongst them.

# %%
sns.regplot(x='H', y='W', data=data)
# Out:
# <AxesSubplot:xlabel='H', ylabel='W'>

# %%
sns.regplot(x='AB', y='W', data=data)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='W'>

# %%
sns.regplot(x='H', y='AB', data=data)
# Out:
# <AxesSubplot:xlabel='H', ylabel='AB'>

# %% [markdown]
# H and AB, both are very weakly related with Win, whereas they are strongly related with each other.

# %% [markdown]
# # Checking Skewness

# %%
x = data.drop(columns = ['W'])
y = data['W']

# %%
x.skew().sort_values(ascending = False)
# Out:
# R         1.200786
# E         0.890132
# CG        0.736845
# H         0.670254
# SV        0.657524
# SHO       0.565790
# HR        0.516441
# SB        0.479893
# AB        0.183437
# BB        0.158498
# Triple    0.129502
# ER        0.058710
# ERA       0.053331
# RA        0.045734
# SO       -0.156065
# Double   -0.230650
# dtype: float64

# %% [markdown]
# There seems to be skewness present in the data, ranging from -0.23 to +1.20.
#
# Therefore, we will use power_transformation function to remove skewness.

# %%
from sklearn.preprocessing import power_transform
x_new = power_transform(x)

# %%
pd.DataFrame(x_new, columns = x.columns).skew().sort_values(ascending = False)
# Out:
# E         0.063909
# SO        0.041170
# SHO       0.006560
# ERA       0.001746
# SV        0.000836
# R         0.000000
# AB        0.000000
# H         0.000000
# HR       -0.000065
# ER       -0.001940
# BB       -0.007760
# RA       -0.008082
# SB       -0.010455
# Double   -0.035315
# CG       -0.059785
# Triple   -0.072933
# dtype: float64

# %% [markdown]
# Now, we can see the skewness is removed.

# %%
x = pd.DataFrame(x_new, columns = x.columns)

x.head()
# Out:
#      R   AB    H    Double    Triple        HR        BB        SO        SB  \
# 0  0.0  0.0  0.0  1.477685  1.033103 -0.764626 -1.610915 -2.569896  0.939708
# 1  0.0  0.0  0.0  0.084269  1.203320 -0.158581 -0.502749  0.134913 -0.539693
# 2  0.0  0.0  0.0  1.670782 -0.160270 -0.689676  1.128294 -0.901254  0.211956
# 3  0.0  0.0  0.0 -0.848600 -0.360521 -0.879049 -1.181207 -0.189628 -0.642564
# 4  0.0  0.0  0.0  0.792183  1.616444 -0.329850 -0.206771  0.085459  0.079629
#
#          RA        ER       ERA        CG       SHO        SV         E
# 0 -0.660331 -0.497425 -0.500893 -0.359844 -0.789579  1.546378 -0.334953
# 1  0.175465  0.257974  0.261806 -0.359844  0.251775  0.360444 -0.532211
# 2 -0.674621 -0.746906 -0.636459  1.993513 -0.245393 -0.607594 -1.342331
# 3  0.189512  0.113575  0.060804  1.220103 -0.510759 -0.764453  0.678524
# 4  1.603228  1.582654  1.520959  1.220103  0.251775 -1.095010 -0.532211

# %%
plt.figure(figsize = (20,20))
plotnumber = 1

for column in x:
    if plotnumber <= 16:
        ax = plt.subplot(4,4,plotnumber)
        sns.distplot(x[column])
        plt.xlabel(column, fontsize = 20)
    plotnumber +=1
plt.tight_layout()

# %% [markdown]
# After removal of skewness from the data, it looks perfectly normalized.

# %%
plt.figure(figsize=(20,25))
fignumber = 1

for column in x:
    if fignumber<= 16:
        ax = plt.subplot(4,4,fignumber)
        sns.regplot(x[column],y)
        
    fignumber +=1
plt.show()

# %% [markdown]
# Observations:
# - The R(number of runs), HR (home runs), 2B(doubles), SV(Saves), SHO(Shutouts), and BB(Walks) are highly positively linearly correlated.
#
# - SB(Stolen Bases), RA(Runs Allowed), ER(Earned Runs), ERA(Earned Runs Average) are highly negative linearly correlated.
#
# - The remaining features have less to no linear correlation with no of Wins.

# %% [markdown]
# # Checking Outliers

# %%
x.iloc[:,:].boxplot(figsize = (20,8))
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [markdown]
# It seems that all the data points are within the range of 3Z.
#
# Let's check using Z-Score

# %%
from scipy.stats import zscore
(np.abs(zscore(x))<3).all()
# Out:
# R         False
# AB        False
# H         False
# Double     True
# Triple     True
# HR         True
# BB         True
# SO         True
# SB         True
# RA         True
# ER         True
# ERA        True
# CG         True
# SHO        True
# SV         True
# E          True
# dtype: bool

# %% [markdown]
# There is no Outlier present in the DataSet.

# %% [markdown]
# ##### Checking Multicollinearity using VIF

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_scaled = scaler.fit_transform(x)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()

vif['vif'] = [variance_inflation_factor(x_scaled, i) for i in range (x_scaled.shape[1])]

vif['features'] = x.columns


# Lets check the values 
vif
# Out:
#            vif features
# 0          NaN        R
# 1          NaN       AB
# 2          NaN        H
# 3     2.221041   Double
# 4     2.697792   Triple
# 5     2.867884       HR
# 6     3.331177       BB
# 7     2.321817       SO
# 8     1.888334       SB
# 9   177.760829       RA
# 10  543.300331       ER
# 11  314.143795      ERA
# 12    2.162372       CG
# 13    3.197808      SHO
# 14    3.518082       SV
# 15    1.711436        E

# %% [markdown]
# AS the value of VIF is very high that means, There is a strong correlation between features. Therefore removing the feature with heighest VIF values and then will see the variation in VIF.

# %%
x_new = x.drop(columns = ['ER'], axis=1)

x_new.head()
# Out:
#      R   AB    H    Double    Triple        HR        BB        SO        SB  \
# 0  0.0  0.0  0.0  1.477685  1.033103 -0.764626 -1.610915 -2.569896  0.939708
# 1  0.0  0.0  0.0  0.084269  1.203320 -0.158581 -0.502749  0.134913 -0.539693
# 2  0.0  0.0  0.0  1.670782 -0.160270 -0.689676  1.128294 -0.901254  0.211956
# 3  0.0  0.0  0.0 -0.848600 -0.360521 -0.879049 -1.181207 -0.189628 -0.642564
# 4  0.0  0.0  0.0  0.792183  1.616444 -0.329850 -0.206771  0.085459  0.079629
#
#          RA       ERA        CG       SHO        SV         E
# 0 -0.660331 -0.500893 -0.359844 -0.789579  1.546378 -0.334953
# 1  0.175465  0.261806 -0.359844  0.251775  0.360444 -0.532211
# 2 -0.674621 -0.636459  1.993513 -0.245393 -0.607594 -1.342331
# 3  0.189512  0.060804  1.220103 -0.510759 -0.764453  0.678524
# 4  1.603228  1.520959  1.220103  0.251775 -1.095010 -0.532211

# %%
scaler = StandardScaler()

x_scaled = scaler.fit_transform(x_new)

# %%
vif = pd.DataFrame()

vif['vif'] = [variance_inflation_factor(x_scaled, i) for i in range (x_scaled.shape[1])]

vif['features'] = x_new.columns


# Lets check the values 
vif
# Out:
#           vif features
# 0         NaN        R
# 1         NaN       AB
# 2         NaN        H
# 3    2.204932   Double
# 4    2.633668   Triple
# 5    2.132582       HR
# 6    3.215413       BB
# 7    2.106638       SO
# 8    1.614637       SB
# 9   92.211410       RA
# 10  94.138582      ERA
# 11   2.157866       CG
# 12   2.785110      SHO
# 13   2.295221       SV
# 14   1.708169        E

# %% [markdown]
# As it can be easily seen that there is a significant drop in VIF value, but still it is high, therefore removing the other feature with High vif value i.e. ER.

# %%
x_new = x_new.drop(columns = ['ERA'], axis=1)

x_new.head()
# Out:
#      R   AB    H    Double    Triple        HR        BB        SO        SB  \
# 0  0.0  0.0  0.0  1.477685  1.033103 -0.764626 -1.610915 -2.569896  0.939708
# 1  0.0  0.0  0.0  0.084269  1.203320 -0.158581 -0.502749  0.134913 -0.539693
# 2  0.0  0.0  0.0  1.670782 -0.160270 -0.689676  1.128294 -0.901254  0.211956
# 3  0.0  0.0  0.0 -0.848600 -0.360521 -0.879049 -1.181207 -0.189628 -0.642564
# 4  0.0  0.0  0.0  0.792183  1.616444 -0.329850 -0.206771  0.085459  0.079629
#
#          RA        CG       SHO        SV         E
# 0 -0.660331 -0.359844 -0.789579  1.546378 -0.334953
# 1  0.175465 -0.359844  0.251775  0.360444 -0.532211
# 2 -0.674621  1.993513 -0.245393 -0.607594 -1.342331
# 3  0.189512  1.220103 -0.510759 -0.764453  0.678524
# 4  1.603228  1.220103  0.251775 -1.095010 -0.532211

# %%
scaler = StandardScaler()

x_scaled = scaler.fit_transform(x_new)

# %%
vif = pd.DataFrame()

vif['vif'] = [variance_inflation_factor(x_scaled, i) for i in range (x_scaled.shape[1])]

vif['features'] = x_new.columns


# Lets check the values 
vif
# Out:
#          vif features
# 0        NaN        R
# 1        NaN       AB
# 2        NaN        H
# 3   1.872458   Double
# 4   2.528202   Triple
# 5   1.838484       HR
# 6   2.780222       BB
# 7   1.789207       SO
# 8   1.600073       SB
# 9   3.779498       RA
# 10  1.896671       CG
# 11  2.785027      SHO
# 12  2.125798       SV
# 13  1.318488        E

# %% [markdown]
# VIF values are reduced compared to earlier, and it ranges below 10 therefore, proceeding ahead with dataset.

# %% [markdown]
# # ML Models

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
max_r2_score = 0
maxRS = 0

for i in range(1,1000):
    x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size = 0.25, random_state = i)
    reg = LinearRegression()
    reg.fit(x_train, y_train)
    y_pred = reg.predict(x_test)
    r2score = r2_score(y_test,y_pred)
    print('r2_score', r2score*100,'%', 'random_state', i)
    
    if r2score > max_r2_score:
        max_r2_score = r2score
        maxRS = i
        print('r2_score', max_r2_score*100,'%', 'random_state', i)
# Out:
# r2_score 44.149171542631095 % random_state 1
# r2_score 44.149171542631095 % random_state 1
# r2_score -27.02625131945011 % random_state 2
# r2_score 25.763454607063842 % random_state 3
# r2_score 76.64585444316144 % random_state 4
# r2_score 76.64585444316144 % random_state 4
# r2_score 56.46016736804501 % random_state 5
# r2_score 78.42026682386518 % random_state 6
# r2_score 78.42026682386518 % random_state 6
# r2_score 72.41137328499963 % random_state 7
# r2_score 65.81234956630767 % random_state 8
# r2_score 38.481322072611576 % random_state 9
# r2_score 32.6321772640831 % random_state 10
# r2_score 25.69957635882195 % random_state 11
# r2_score -31.322023215943684 % random_state 12
# r2_score 40.167119859670244 % random_state 13
# r2_score 72.07796966081337 % random_state 14
# r2_score 26.36529678622467 % random_state 15
# r2_score 26.469632358494078 % random_state 16
# r2_score 52.664605565051644 % random_state 17
# r2_score 34.56477998106774 % random_state 18
# r2_score 77.59778722221894 % random_state 19
# r2_score 34.379050120594066 % random_state 20
# r2_score 49.03856811205035 % random_state 21
# r2_score 50.64869279930599 % random_state 22
# r2_score 80.86080072329965 % random_state 23
# r2_score 80.86080072329965 % random_state 23
# r2_score -424.1187500053888 % random_state 24
# r2_score 11.517157165183345 % random_state 25
# r2_score 27.85351743397515 % random_state 26
# r2_score 90.0274527519269 % random_state 27
# r2_score 90.0274527519269 % random_state 27
# r2_score 38.41672568472093 % random_state 28
# r2_score 76.32946355395002 % random_state 29
# r2_score 59.64691020979962 % random_state 30
# r2_score -15.110117802177125 % random_state 31
# r2_score 74.94120098201786 % random_state 32
# r2_score 46.42721431041007 % random_state 33
# r2_score 58.97480964426486 % random_state 34
# r2_score 16.30021163264993 % random_state 35
# r2_score -12.236894308108726 % random_state 36
# r2_score 24.56538945458373 % random_state 37
# r2_score 31.669133530373518 % random_state 38
# r2_score 65.98723515302174 % random_state 39
# r2_score 51.99876391853777 % random_state 40
# r2_score 64.79570529262875 % random_state 41
# r2_score 75.60333755212395 % random_state 42
# r2_score -147.90786159808926 % random_state 43
# r2_score 64.06669732953851 % random_state 44
# r2_score 39.91212754343195 % random_state 45
# r2_score 60.21351875638986 % random_state 46
# r2_score 37.53946979231293 % random_state 47
# r2_score 88.29010513032885 % random_state 48
# r2_score 5.213887802449091 % random_state 49
# r2_score 54.00205000871614 % random_state 50
# r2_score 54.16415078711934 % random_state 51
# r2_score -56.20328075537093 % random_state 52
# r2_score 59.23057577640607 % random_state 53
# r2_score 64.29619071123538 % random_state 54
# r2_score 29.051561466991604 % random_state 55
# r2_score 23.73992453789635 % random_state 56
# r2_score -15.30323605821331 % random_state 57
# r2_score 52.96874675753249 % random_state 58
# r2_score 38.031831415840976 % random_state 59
# r2_score -34.26741738580552 % random_state 60
# r2_score -126.93449373857489 % random_state 61
# r2_score -219.0225324645739 % random_state 62
# r2_score 39.75436112151118 % random_state 63
# r2_score 74.51398069565138 % random_state 64
# r2_score 53.32540506980394 % random_state 65
# r2_score -34.758089306991245 % random_state 66
# r2_score -22.121427903100876 % random_state 67
# r2_score -60.56088619570787 % random_state 68
# r2_score 47.442853585427805 % random_state 69
# r2_score 65.46893270289489 % random_state 70
# r2_score -171.21968999924982 % random_state 71
# r2_score 27.66538316617295 % random_state 72
# r2_score 74.97071064275363 % random_state 73
# r2_score 67.44121277220418 % random_state 74
# r2_score 67.08369226015246 % random_state 75
# r2_score 25.53279822410578 % random_state 76
# r2_score 52.44676258928933 % random_state 77
# r2_score 26.77714732733175 % random_state 78
# r2_score 12.803909868024355 % random_state 79
# r2_score -31.924362058520074 % random_state 80
# r2_score -385.1910587641213 % random_state 81
# r2_score 55.604255411555194 % random_state 82
# r2_score 66.00075859486871 % random_state 83
# r2_score 37.60164708163812 % random_state 84
# r2_score 37.79240088840673 % random_state 85
# r2_score 74.83949882097717 % random_state 86
# r2_score 49.341508855103086 % random_state 87
# r2_score -61.40773590711288 % random_state 88
# r2_score 77.92703083326025 % random_state 89
# r2_score 59.048277505245196 % random_state 90
# r2_score -2.2329403828902805 % random_state 91
# r2_score 26.39130845508285 % random_state 92
# r2_score 38.181386700175835 % random_state 93
# r2_score 43.0413904855777 % random_state 94
# r2_score -12.175283133382697 % random_state 95
# r2_score 67.02367433510464 % random_state 96
# r2_score 39.52198689357036 % random_state 97
# r2_score 39.29845466095656 % random_state 98
# r2_score 77.88559843583597 % random_state 99
# r2_score 56.200416169720825 % random_state 100
# r2_score 46.1348665322463 % random_state 101
# r2_score 16.897158184975357 % random_state 102
# r2_score 80.21589990801716 % random_state 103
# r2_score 79.9323332144503 % random_state 104
# r2_score 13.780837504888055 % random_state 105
# r2_score 1.7099941750679748 % random_state 106
# r2_score 61.979164705077714 % random_state 107
# r2_score 22.3189879182511 % random_state 108
# r2_score -63.81468694306729 % random_state 109
# r2_score 17.06701110456632 % random_state 110
# r2_score -38.44436003493894 % random_state 111
# r2_score 66.62409413186779 % random_state 112
# r2_score 9.487322938473364 % random_state 113
# r2_score 73.28218113939384 % random_state 114
# r2_score 42.378763611780045 % random_state 115
# r2_score 67.90680754611031 % random_state 116
# r2_score 17.489044693352838 % random_state 117
# r2_score 47.72748456198316 % random_state 118
# r2_score 67.52767149471661 % random_state 119
# r2_score 10.918598928144407 % random_state 120
# r2_score 69.20433153516876 % random_state 121
# r2_score 19.691638515081745 % random_state 122
# r2_score -46.81604469930309 % random_state 123
# r2_score 40.430843694038145 % random_state 124
# r2_score 33.77210008174746 % random_state 125
# r2_score -27.29207877830313 % random_state 126
# r2_score 17.978072217019214 % random_state 127
# r2_score -48.257099793828 % random_state 128
# r2_score 84.49411252365392 % random_state 129
# r2_score 65.98342865519886 % random_state 130
# r2_score -11.702714495267564 % random_state 131
# r2_score 32.16972106654248 % random_state 132
# r2_score -11.670237913217218 % random_state 133
# r2_score 1.8497865284344939 % random_state 134
# r2_score 75.34322747413918 % random_state 135
# r2_score 29.085433528669736 % random_state 136
# r2_score 61.492997441364714 % random_state 137
# r2_score 0.5048761157929738 % random_state 138
# r2_score -30.75369768818479 % random_state 139
# r2_score 41.04305431307414 % random_state 140
# r2_score 53.78509628531256 % random_state 141
# r2_score 54.57522991990742 % random_state 142
# r2_score 25.707780836614337 % random_state 143
# r2_score 58.49109195521979 % random_state 144
# r2_score 41.842979478851795 % random_state 145
# r2_score 43.476241760716526 % random_state 146
# r2_score -40.340205475868565 % random_state 147
# r2_score 62.22901308989297 % random_state 148
# r2_score 47.38549396629966 % random_state 149
# r2_score 42.31835314776548 % random_state 150
# r2_score -45.12416284782854 % random_state 151
# r2_score 19.103082377865476 % random_state 152
# r2_score -10.106191545457133 % random_state 153
# r2_score -23.066740313659984 % random_state 154
# r2_score 80.5937711321625 % random_state 155
# r2_score -73.2425832791353 % random_state 156
# r2_score 47.696123592492555 % random_state 157
# r2_score 29.67557337360496 % random_state 158
# r2_score 69.34898385882676 % random_state 159
# r2_score -8.566993788735179 % random_state 160
# r2_score 48.94955750184927 % random_state 161
# r2_score 80.51280156766038 % random_state 162
# r2_score 63.86639549708699 % random_state 163
# r2_score 19.21974722406301 % random_state 164
# r2_score 78.0125352456174 % random_state 165
# r2_score -60.19083910797129 % random_state 166
# r2_score 76.39525709288391 % random_state 167
# r2_score 34.91098972746747 % random_state 168
# r2_score 9.457522570605004 % random_state 169
# r2_score 52.66389371114511 % random_state 170
# r2_score 62.71943627259788 % random_state 171
# r2_score -2.988303208164922 % random_state 172
# r2_score -10.279783210897486 % random_state 173
# r2_score -65.17447096292874 % random_state 174
# r2_score 84.67318272606661 % random_state 175
# r2_score 21.64604981804159 % random_state 176
# r2_score 66.7473960547746 % random_state 177
# r2_score 67.71043225097858 % random_state 178
# r2_score 24.13507241827907 % random_state 179
# r2_score 81.02613767011846 % random_state 180
# r2_score 26.48762739243181 % random_state 181
# r2_score 47.805707080966705 % random_state 182
# r2_score -31.36799969909263 % random_state 183
# r2_score -82.82395414461783 % random_state 184
# r2_score 45.44253870693772 % random_state 185
# r2_score 42.830818531767434 % random_state 186
# r2_score -6.365107581318719 % random_state 187
# r2_score 18.444345337410194 % random_state 188
# r2_score 80.77820182024834 % random_state 189
# r2_score 51.649990964091764 % random_state 190
# r2_score 73.86711114482544 % random_state 191
# r2_score -171.50785388686262 % random_state 192
# r2_score 67.921021188972 % random_state 193
# r2_score -14.472757159482509 % random_state 194
# r2_score 61.19648449962376 % random_state 195
# r2_score 73.03009470452946 % random_state 196
# r2_score 61.89292959153513 % random_state 197
# r2_score 62.127522073012955 % random_state 198
# r2_score 24.23953734740666 % random_state 199
# r2_score 59.496859151323235 % random_state 200
# r2_score -28.814466036617723 % random_state 201
# r2_score 45.44489047410626 % random_state 202
# r2_score -39.97366791814976 % random_state 203
# r2_score -20.38738930726609 % random_state 204
# r2_score 60.51469360782217 % random_state 205
# r2_score 32.237364188684836 % random_state 206
# r2_score 69.66419841701253 % random_state 207
# r2_score 60.4514733103234 % random_state 208
# r2_score -41.76642119248017 % random_state 209
# r2_score 45.768908548407374 % random_state 210
# r2_score -15.59177185785845 % random_state 211
# r2_score 36.26188278144209 % random_state 212
# r2_score 45.2148312345778 % random_state 213
# r2_score 26.942530932285347 % random_state 214
# r2_score 52.237892492468454 % random_state 215
# r2_score -5.040545694054366 % random_state 216
# r2_score 59.07732739501337 % random_state 217
# r2_score 64.43586791399933 % random_state 218
# r2_score -5.31320818345411 % random_state 219
# r2_score 1.5028806645051906 % random_state 220
# r2_score 56.26114777059586 % random_state 221
# r2_score 51.49064983291169 % random_state 222
# r2_score 20.396812659857133 % random_state 223
# r2_score 57.27611181617904 % random_state 224
# r2_score 61.53970066781507 % random_state 225
# r2_score 50.65867044619794 % random_state 226
# r2_score 71.42867811179912 % random_state 227
# r2_score -24.2945520109082 % random_state 228
# r2_score 76.20217391665966 % random_state 229
# r2_score 68.41527328855435 % random_state 230
# r2_score 39.0614174526689 % random_state 231
# r2_score 19.609737060262276 % random_state 232
# r2_score -19.911795705362966 % random_state 233
# r2_score 19.180656545171647 % random_state 234
# r2_score -223.952809222307 % random_state 235
# r2_score 9.773745373910591 % random_state 236
# r2_score 50.514462324428564 % random_state 237
# r2_score -11.941119115520493 % random_state 238
# r2_score 45.705380518542135 % random_state 239
# r2_score 50.03169914969045 % random_state 240
# r2_score -8.89069514342622 % random_state 241
# r2_score 52.467365299667016 % random_state 242
# r2_score 58.798108103381054 % random_state 243
# r2_score 68.13855598536851 % random_state 244
# r2_score -74.26725365911715 % random_state 245
# r2_score 84.92232839923605 % random_state 246
# r2_score 17.62213397291964 % random_state 247
# r2_score 45.855182840523476 % random_state 248
# r2_score 79.46290760989699 % random_state 249
# r2_score 42.45911981989734 % random_state 250
# r2_score 58.234137010936784 % random_state 251
# r2_score 37.1223322798645 % random_state 252
# r2_score -88.768107638931 % random_state 253
# r2_score 86.9479025373625 % random_state 254
# r2_score -19.451808633598432 % random_state 255
# r2_score 11.422012529889802 % random_state 256
# r2_score -17.32312675245653 % random_state 257
# r2_score 22.256439856759336 % random_state 258
# r2_score 82.33600966670637 % random_state 259
# r2_score -31.094187765910263 % random_state 260
# r2_score -36.41856890138371 % random_state 261
# r2_score 14.346960086109451 % random_state 262
# r2_score 51.07083693746461 % random_state 263
# r2_score 46.423499830856905 % random_state 264
# r2_score 42.699068011614536 % random_state 265
# r2_score 39.862179609468484 % random_state 266
# r2_score 46.17685297199409 % random_state 267
# r2_score 37.078365999996144 % random_state 268
# r2_score 64.4817690175553 % random_state 269
# r2_score 66.19159308939255 % random_state 270
# r2_score 31.560787475342835 % random_state 271
# r2_score 70.43522347047619 % random_state 272
# r2_score 70.55928595270579 % random_state 273
# r2_score 77.61368173813005 % random_state 274
# r2_score 58.92782341856415 % random_state 275
# r2_score 36.42128915074404 % random_state 276
# r2_score 45.57379855995133 % random_state 277
# r2_score 23.026526922607182 % random_state 278
# r2_score -32.86137073520905 % random_state 279
# r2_score 53.6367353634414 % random_state 280
# r2_score 60.26937691063432 % random_state 281
# r2_score 77.70658941234727 % random_state 282
# r2_score 55.54388378800188 % random_state 283
# r2_score -3.020114340687985 % random_state 284
# r2_score 63.034791331446435 % random_state 285
# r2_score -26.379204945621517 % random_state 286
# r2_score 55.17853157177144 % random_state 287
# r2_score 55.87560260040683 % random_state 288
# r2_score 57.55716678846283 % random_state 289
# r2_score 45.955396549290114 % random_state 290
# r2_score -23.493710097263577 % random_state 291
# r2_score 58.630503632927564 % random_state 292
# r2_score 33.56300035914877 % random_state 293
# r2_score 12.435731848662911 % random_state 294
# r2_score -44.46997864762794 % random_state 295
# r2_score 80.68569778736394 % random_state 296
# r2_score -83.89619227865089 % random_state 297
# r2_score 2.758406182577988 % random_state 298
# r2_score 58.719519792908144 % random_state 299
# r2_score 54.984999391058956 % random_state 300
# r2_score 79.227989929581 % random_state 301
# r2_score 74.39396770138687 % random_state 302
# r2_score 52.36459950163152 % random_state 303
# r2_score 69.91833664370222 % random_state 304
# r2_score -31.03876983803748 % random_state 305
# r2_score 0.08957413406150971 % random_state 306
# r2_score 51.01636724098056 % random_state 307
# r2_score 13.570750082664452 % random_state 308
# r2_score 0.42333226743394015 % random_state 309
# r2_score 74.27833040922962 % random_state 310
# r2_score 73.07066622078693 % random_state 311
# r2_score 30.449497902292823 % random_state 312
# r2_score 52.85436546029408 % random_state 313
# r2_score 59.45041264205679 % random_state 314
# r2_score 52.231251601436426 % random_state 315
# r2_score 37.23616448554464 % random_state 316
# r2_score 50.17990225612936 % random_state 317
# r2_score -60.17113532836136 % random_state 318
# r2_score 22.26916004118712 % random_state 319
# r2_score 68.3979675655968 % random_state 320
# r2_score 80.88746677131668 % random_state 321
# r2_score 23.933992869989652 % random_state 322
# r2_score 73.68542938368127 % random_state 323
# r2_score 45.64152993621573 % random_state 324
# r2_score 40.50915189172567 % random_state 325
# r2_score -9.917414189602148 % random_state 326
# r2_score 56.09932742163581 % random_state 327
# r2_score 22.48323155978521 % random_state 328
# r2_score -10.623133691112962 % random_state 329
# r2_score 29.77260213818117 % random_state 330
# r2_score 35.90472804594471 % random_state 331
# r2_score -17.66794496291595 % random_state 332
# r2_score -10.530651587533013 % random_state 333
# r2_score 77.55438507673644 % random_state 334
# r2_score 73.12268694944906 % random_state 335
# r2_score 1.5016264833403459 % random_state 336
# r2_score -81.92655854885356 % random_state 337
# r2_score -226.94313680144157 % random_state 338
# r2_score 77.23333084071353 % random_state 339
# r2_score -57.95275233412311 % random_state 340
# r2_score -15.484456546988866 % random_state 341
# r2_score -86.96339262733818 % random_state 342
# r2_score 35.945162258707754 % random_state 343
# r2_score 50.310405258753676 % random_state 344
# r2_score 40.34216851725472 % random_state 345
# r2_score 29.904019224922706 % random_state 346
# r2_score 71.13922679993469 % random_state 347
# r2_score 66.22027394826075 % random_state 348
# r2_score 52.812239892293334 % random_state 349
# r2_score 86.52305171238825 % random_state 350
# r2_score 63.31795651896145 % random_state 351
# r2_score 41.825841317882464 % random_state 352
# r2_score 65.31501119785536 % random_state 353
# r2_score 61.17376676636318 % random_state 354
# r2_score 29.69628477331493 % random_state 355
# r2_score 64.63919501623596 % random_state 356
# r2_score 59.4460943412325 % random_state 357
# r2_score -23.635707188953802 % random_state 358
# r2_score 56.409929859743144 % random_state 359
# r2_score 3.29063838039092 % random_state 360
# r2_score 59.641989992465675 % random_state 361
# r2_score 56.42649075440344 % random_state 362
# r2_score 23.228882290788498 % random_state 363
# r2_score 25.47140881530713 % random_state 364
# r2_score 61.828100651504656 % random_state 365
# r2_score 64.78707005974896 % random_state 366
# r2_score 59.98336055811411 % random_state 367
# r2_score 35.769312305982105 % random_state 368
# r2_score 36.83955847365043 % random_state 369
# r2_score 79.65485134190409 % random_state 370
# r2_score 74.115321206776 % random_state 371
# r2_score -4.480924425540156 % random_state 372
# r2_score 56.30389767136109 % random_state 373
# r2_score -64.11070600374109 % random_state 374
# r2_score 42.18710218772379 % random_state 375
# r2_score 82.58114068896388 % random_state 376
# r2_score 40.814247274855965 % random_state 377
# r2_score -72.00121351447959 % random_state 378
# r2_score 66.19629758477197 % random_state 379
# r2_score 35.97283782355654 % random_state 380
# r2_score 27.065433923490822 % random_state 381
# r2_score 45.00535606783942 % random_state 382
# r2_score 70.37053234905002 % random_state 383
# r2_score 54.441288965244006 % random_state 384
# r2_score 54.06060936287349 % random_state 385
# r2_score -185.5940851289077 % random_state 386
# r2_score 37.03358868192888 % random_state 387
# r2_score 73.75492143051011 % random_state 388
# r2_score 49.83365849181145 % random_state 389
# r2_score 26.59011625665162 % random_state 390
# r2_score -124.80841546672656 % random_state 391
# r2_score 70.21419840056421 % random_state 392
# r2_score 45.20011099765896 % random_state 393
# r2_score 86.40591087170623 % random_state 394
# r2_score 29.66265649703135 % random_state 395
# r2_score 8.929301327077843 % random_state 396
# r2_score 39.486979491018346 % random_state 397
# r2_score 66.84677990112459 % random_state 398
# r2_score 73.52078483576949 % random_state 399
# r2_score 18.601511350517864 % random_state 400
# r2_score 56.387011822472196 % random_state 401
# r2_score 56.30462148208918 % random_state 402
# r2_score -139.6905375820221 % random_state 403
# r2_score 56.04408356929076 % random_state 404
# r2_score -1.8595354226383476 % random_state 405
# r2_score 31.30940960529992 % random_state 406
# r2_score -2.6356351645801412 % random_state 407
# r2_score 80.41229831036394 % random_state 408
# r2_score 16.030472242434524 % random_state 409
# r2_score 58.81347423010518 % random_state 410
# r2_score 50.68842283625562 % random_state 411
# r2_score 30.921130755928573 % random_state 412
# r2_score 42.752371031561054 % random_state 413
# r2_score 15.028035817647933 % random_state 414
# r2_score -8.044066347815292 % random_state 415
# r2_score 23.173524937742396 % random_state 416
# r2_score 50.758750486284086 % random_state 417
# r2_score 66.65043543053255 % random_state 418
# r2_score 52.91922283882968 % random_state 419
# r2_score 80.82611435567438 % random_state 420
# r2_score 18.686627889946926 % random_state 421
# r2_score 54.430092097616935 % random_state 422
# r2_score 49.39481336701914 % random_state 423
# r2_score 87.72836004649459 % random_state 424
# r2_score 44.670121312781795 % random_state 425
# r2_score 55.76729472471336 % random_state 426
# r2_score 59.284019533049694 % random_state 427
# r2_score 53.3202993725647 % random_state 428
# r2_score 61.886746973391546 % random_state 429
# r2_score 47.5996590084007 % random_state 430
# r2_score -216.78586037508256 % random_state 431
# r2_score -13.443180110463949 % random_state 432
# r2_score 72.11241833136319 % random_state 433
# r2_score 32.06173438207441 % random_state 434
# r2_score 53.982465802672905 % random_state 435
# r2_score -6.277236536056674 % random_state 436
# r2_score 1.5962597867790196 % random_state 437
# r2_score -227.26124671819753 % random_state 438
# r2_score 25.88120769324117 % random_state 439
# r2_score -237.83066511054 % random_state 440
# r2_score 58.900079984150636 % random_state 441
# r2_score 45.38975202585151 % random_state 442
# r2_score 3.5335010195704397 % random_state 443
# r2_score 56.400489625715224 % random_state 444
# r2_score 22.664077831961905 % random_state 445
# r2_score 59.537430927967236 % random_state 446
# r2_score 84.79351576592623 % random_state 447
# r2_score 35.73723441526524 % random_state 448
# r2_score -106.57583735057932 % random_state 449
# r2_score 72.40390354531553 % random_state 450
# r2_score 68.04208059822324 % random_state 451
# r2_score 21.766633295293857 % random_state 452
# r2_score 54.233694121221276 % random_state 453
# r2_score 63.9059485616315 % random_state 454
# r2_score 60.514533181060216 % random_state 455
# r2_score 38.94850887433522 % random_state 456
# r2_score 23.202442329777462 % random_state 457
# r2_score -29.45606802146372 % random_state 458
# r2_score 45.53073103191401 % random_state 459
# r2_score -60.02831884013386 % random_state 460
# r2_score -446.87402378931216 % random_state 461
# r2_score 8.943895872312646 % random_state 462
# r2_score -115.49350853360872 % random_state 463
# r2_score 51.3777760460997 % random_state 464
# r2_score 34.13168140686121 % random_state 465
# r2_score 39.88422918150335 % random_state 466
# r2_score 65.38239539820415 % random_state 467
# r2_score 43.795534792689764 % random_state 468
# r2_score 58.30443769344167 % random_state 469
# r2_score 21.161764630654567 % random_state 470
# r2_score 73.13421399302598 % random_state 471
# r2_score 29.612094956834788 % random_state 472
# r2_score 63.91744946416449 % random_state 473
# r2_score 41.12156076682163 % random_state 474
# r2_score -18.46243438351316 % random_state 475
# r2_score -39.499361415291176 % random_state 476
# r2_score 19.655839787639763 % random_state 477
# r2_score 51.46864020701203 % random_state 478
# r2_score 53.98738815953058 % random_state 479
# r2_score 51.77535154916816 % random_state 480
# r2_score 40.60962107556638 % random_state 481
# r2_score 50.05326239755086 % random_state 482
# r2_score 54.10834421253511 % random_state 483
# r2_score 55.122017751226274 % random_state 484
# r2_score 43.67572208249466 % random_state 485
# r2_score 50.14406938049366 % random_state 486
# r2_score 79.19409118964636 % random_state 487
# r2_score 53.724031951821296 % random_state 488
# r2_score 40.77972319087304 % random_state 489
# r2_score 37.31296034001049 % random_state 490
# r2_score 29.938340076467895 % random_state 491
# r2_score 55.28151992529079 % random_state 492
# r2_score 60.80077649582765 % random_state 493
# r2_score 8.664720273742343 % random_state 494
# r2_score 63.885976771875775 % random_state 495
# r2_score 38.87041338803663 % random_state 496
# r2_score -36.42539483171014 % random_state 497
# r2_score 56.14159396572504 % random_state 498
# r2_score -20.12408548596838 % random_state 499
# r2_score 39.11650718805332 % random_state 500
# r2_score -20.464518868593508 % random_state 501
# r2_score -68.96693005032945 % random_state 502
# r2_score 42.429822906319814 % random_state 503
# r2_score 39.70199625915788 % random_state 504
# r2_score 53.95820160248208 % random_state 505
# r2_score 59.126949185852 % random_state 506
# r2_score 33.71224045144275 % random_state 507
# r2_score -6.179059559397615 % random_state 508
# r2_score 58.771640513133285 % random_state 509
# r2_score 10.086994037300679 % random_state 510
# r2_score 36.63322934298172 % random_state 511
# r2_score 62.05091989921214 % random_state 512
# r2_score -84.94665240289932 % random_state 513
# r2_score 51.9049153303363 % random_state 514
# r2_score 55.46675413949864 % random_state 515
# r2_score 82.41587600525864 % random_state 516
# r2_score 1.5205791208703245 % random_state 517
# r2_score 49.232933444158746 % random_state 518
# r2_score -94.83502989742145 % random_state 519
# r2_score 73.41551300292997 % random_state 520
# r2_score 63.75218306750763 % random_state 521
# r2_score 54.46944842236474 % random_state 522
# r2_score 23.96802107345192 % random_state 523
# r2_score 32.30932166712911 % random_state 524
# r2_score 21.787305167870553 % random_state 525
# r2_score 57.222761381028086 % random_state 526
# r2_score 64.05650283527078 % random_state 527
# r2_score 9.933065765339066 % random_state 528
# r2_score 55.56879738411913 % random_state 529
# r2_score -15.064098802616655 % random_state 530
# r2_score 56.44440942734323 % random_state 531
# r2_score 52.94137201831324 % random_state 532
# r2_score 46.46612797554478 % random_state 533
# r2_score 75.87794435852355 % random_state 534
# r2_score 54.114171574590756 % random_state 535
# r2_score 23.795020055143766 % random_state 536
# r2_score 20.913295171817182 % random_state 537
# r2_score -85.2061577695155 % random_state 538
# r2_score 47.40765787894009 % random_state 539
# r2_score 42.208736597124066 % random_state 540
# r2_score 54.79036721055043 % random_state 541
# r2_score 33.91502542654919 % random_state 542
# r2_score 24.278143026875544 % random_state 543
# r2_score -124.36090115159755 % random_state 544
# r2_score 76.97745453869406 % random_state 545
# r2_score 54.042746885485826 % random_state 546
# r2_score 47.65714673795023 % random_state 547
# r2_score -40.10637041160601 % random_state 548
# r2_score -45.57845473722097 % random_state 549
# r2_score -69.49256947846168 % random_state 550
# r2_score 71.7995764850717 % random_state 551
# r2_score 68.57661834249089 % random_state 552
# r2_score 16.624677972407078 % random_state 553
# r2_score 57.57170114399723 % random_state 554
# r2_score 35.32769830223492 % random_state 555
# r2_score 60.61322197631341 % random_state 556
# r2_score 29.66235521476339 % random_state 557
# r2_score -42.48917025961823 % random_state 558
# r2_score 53.7976845323527 % random_state 559
# r2_score 43.239421302894755 % random_state 560
# r2_score 53.863669374542475 % random_state 561
# r2_score -60.3496111706985 % random_state 562
# r2_score -34.684004172916374 % random_state 563
# r2_score 38.88742150834326 % random_state 564
# r2_score 81.19215822444008 % random_state 565
# r2_score -146.42459258551375 % random_state 566
# r2_score 59.330260427360706 % random_state 567
# r2_score 54.539427203625266 % random_state 568
# r2_score 50.1395342999178 % random_state 569
# r2_score 41.637956252309586 % random_state 570
# r2_score 53.94654989291037 % random_state 571
# r2_score 56.88444420727985 % random_state 572
# r2_score 67.9834831393988 % random_state 573
# r2_score 15.230677658414205 % random_state 574
# r2_score -51.47203129673967 % random_state 575
# r2_score -46.14717017294192 % random_state 576
# r2_score 56.287430184819286 % random_state 577
# r2_score 46.50291409025083 % random_state 578
# r2_score 7.137706904260055 % random_state 579
# r2_score -15.286239321864482 % random_state 580
# r2_score 70.22207736317225 % random_state 581
# r2_score 54.622597249899485 % random_state 582
# r2_score 15.415962341281187 % random_state 583
# r2_score 34.58368069376988 % random_state 584
# r2_score 35.53602438599059 % random_state 585
# r2_score 65.77919356459498 % random_state 586
# r2_score 37.41544249560904 % random_state 587
# r2_score 41.020219655531584 % random_state 588
# r2_score 6.675194091153081 % random_state 589
# r2_score -168.08918860519896 % random_state 590
# r2_score 37.14726212438343 % random_state 591
# r2_score 44.764115036807226 % random_state 592
# r2_score 58.22968982319397 % random_state 593
# r2_score 79.76101995859898 % random_state 594
# r2_score 45.727896168992835 % random_state 595
# r2_score 79.03551574458535 % random_state 596
# r2_score 55.099874707590814 % random_state 597
# r2_score -1.747936847318865 % random_state 598
# r2_score 11.545932965652439 % random_state 599
# r2_score -139.59487402794005 % random_state 600
# r2_score 26.124385641660385 % random_state 601
# r2_score -13.350539593816535 % random_state 602
# r2_score -115.90462858405117 % random_state 603
# r2_score -43.787404441372324 % random_state 604
# r2_score -29.546530318978228 % random_state 605
# r2_score 39.98006311426092 % random_state 606
# r2_score -5.429377978556449 % random_state 607
# r2_score 63.481056253093726 % random_state 608
# r2_score 59.98587165017463 % random_state 609
# r2_score 67.661007381667 % random_state 610
# r2_score 68.3439129504614 % random_state 611
# r2_score 57.97222322971314 % random_state 612
# r2_score -2.4841161960142077 % random_state 613
# r2_score 59.66437412802903 % random_state 614
# r2_score 59.102724630354 % random_state 615
# r2_score -42.22197778978036 % random_state 616
# r2_score 75.60119105939869 % random_state 617
# r2_score 25.93511815943703 % random_state 618
# r2_score 38.812205502336084 % random_state 619
# r2_score 6.626105621378198 % random_state 620
# r2_score -34.25555286670523 % random_state 621
# r2_score 49.929237355166855 % random_state 622
# r2_score 85.74569651749533 % random_state 623
# r2_score -37.34989712003889 % random_state 624
# r2_score -72.2842782903022 % random_state 625
# r2_score -54.807826940599156 % random_state 626
# r2_score 27.405948280373494 % random_state 627
# r2_score 61.59975429351178 % random_state 628
# r2_score 85.80186965576104 % random_state 629
# r2_score 40.93502668287508 % random_state 630
# r2_score 31.385805252462163 % random_state 631
# r2_score 46.881784409113656 % random_state 632
# r2_score 16.54313813605468 % random_state 633
# r2_score -70.28502427106098 % random_state 634
# r2_score 52.974732430414086 % random_state 635
# r2_score 11.891831332833046 % random_state 636
# r2_score -163.00915689184538 % random_state 637
# r2_score 31.527756149025688 % random_state 638
# r2_score 66.4803220049888 % random_state 639
# r2_score -11.185107121984439 % random_state 640
# r2_score -36.84902286529053 % random_state 641
# r2_score -58.58912636994966 % random_state 642
# r2_score -3.287989799663893 % random_state 643
# r2_score 50.61273952950517 % random_state 644
# r2_score 71.58014988315813 % random_state 645
# r2_score -68.00163674484732 % random_state 646
# r2_score -22.201737401654054 % random_state 647
# r2_score -54.535461322389466 % random_state 648
# r2_score 31.28453631326814 % random_state 649
# r2_score 35.29425056337326 % random_state 650
# r2_score 57.74352162626653 % random_state 651
# r2_score 84.78856681430521 % random_state 652
# r2_score 37.48640914084793 % random_state 653
# r2_score 34.26942058570091 % random_state 654
# r2_score 43.312784318934035 % random_state 655
# r2_score 64.80673292989987 % random_state 656
# r2_score 76.11784011110471 % random_state 657
# r2_score 82.01957819923808 % random_state 658
# r2_score 84.09324940836613 % random_state 659
# r2_score 42.843315085595265 % random_state 660
# r2_score 30.527925172697945 % random_state 661
# r2_score -36.07017993314556 % random_state 662
# r2_score 13.67515768073454 % random_state 663
# r2_score 72.92102422719702 % random_state 664
# r2_score 65.85717159476023 % random_state 665
# r2_score 36.11323319958134 % random_state 666
# r2_score 54.851878291711486 % random_state 667
# r2_score 80.56005232161884 % random_state 668
# r2_score 47.97912647426629 % random_state 669
# r2_score 70.09072895426817 % random_state 670
# r2_score -146.71931689144495 % random_state 671
# r2_score -129.62065102431626 % random_state 672
# r2_score 51.85920061612118 % random_state 673
# r2_score -14.824761468594772 % random_state 674
# r2_score 7.345125466034541 % random_state 675
# r2_score 27.83161861819924 % random_state 676
# r2_score 25.775883789406905 % random_state 677
# r2_score 90.1562545878886 % random_state 678
# r2_score 90.1562545878886 % random_state 678
# r2_score 81.1783081593553 % random_state 679
# r2_score 64.05246503764317 % random_state 680
# r2_score -17.599561062367087 % random_state 681
# r2_score -15.282656792656413 % random_state 682
# r2_score 39.81028295242922 % random_state 683
# r2_score 57.590329231067514 % random_state 684
# r2_score 76.65183597447802 % random_state 685
# r2_score -18.54482122672443 % random_state 686
# r2_score -7.229496561066107 % random_state 687
# r2_score -250.86825222440407 % random_state 688
# r2_score 40.91026379032818 % random_state 689
# r2_score 48.17590618696356 % random_state 690
# r2_score 50.131114740534265 % random_state 691
# r2_score 6.74475502291072 % random_state 692
# r2_score -80.24234417431298 % random_state 693
# r2_score -28.74733429595686 % random_state 694
# r2_score 75.17244442780647 % random_state 695
# r2_score 48.59715659456002 % random_state 696
# r2_score 53.14073937820136 % random_state 697
# r2_score 54.33925133851751 % random_state 698
# r2_score 20.875922402527035 % random_state 699
# r2_score 35.720294718423105 % random_state 700
# r2_score 71.77570680833384 % random_state 701
# r2_score -17.034363996650725 % random_state 702
# r2_score 78.0087344267491 % random_state 703
# r2_score 51.02308994402066 % random_state 704
# r2_score 79.87316616766824 % random_state 705
# r2_score 39.02204746032323 % random_state 706
# r2_score 28.203903084344283 % random_state 707
# r2_score 12.989166539982522 % random_state 708
# r2_score 12.510447319194428 % random_state 709
# r2_score 14.085324799841947 % random_state 710
# r2_score 80.35888643972322 % random_state 711
# r2_score 34.165176269452814 % random_state 712
# r2_score 61.586841111522325 % random_state 713
# r2_score 31.213115199179043 % random_state 714
# r2_score -24.420316409877408 % random_state 715
# r2_score -51.77168001435861 % random_state 716
# r2_score 47.73118454470352 % random_state 717
# r2_score 27.422723647435333 % random_state 718
# r2_score 75.09153513198252 % random_state 719
# r2_score 6.311085513468684 % random_state 720
# r2_score 70.82102997486513 % random_state 721
# r2_score -4.077367224299366 % random_state 722
# r2_score 45.0047531094029 % random_state 723
# r2_score 39.55360529116357 % random_state 724
# r2_score 64.28970362810391 % random_state 725
# r2_score 37.397870671727 % random_state 726
# r2_score 57.9831276361928 % random_state 727
# r2_score 74.46489122487165 % random_state 728
# r2_score 51.46782987733709 % random_state 729
# r2_score 29.634434384374742 % random_state 730
# r2_score 12.27873313810025 % random_state 731
# r2_score -16.315243711250304 % random_state 732
# r2_score 2.30436779075035 % random_state 733
# r2_score 85.50742568013644 % random_state 734
# r2_score 4.791083863762713 % random_state 735
# r2_score 57.57145606643562 % random_state 736
# r2_score 61.30827192417869 % random_state 737
# r2_score 1.9846345070944071 % random_state 738
# r2_score 1.7452716354438236 % random_state 739
# r2_score 63.04076971126265 % random_state 740
# r2_score 65.92228752520819 % random_state 741
# r2_score 36.924402030799406 % random_state 742
# r2_score 75.73821404489662 % random_state 743
# r2_score 30.337796383344973 % random_state 744
# r2_score -78.77417203219714 % random_state 745
# r2_score 7.342456440677614 % random_state 746
# r2_score 28.60061774086875 % random_state 747
# r2_score 87.46531356774783 % random_state 748
# r2_score 64.95914701094264 % random_state 749
# r2_score -9.224560914539914 % random_state 750
# r2_score 65.67054206182644 % random_state 751
# r2_score 65.19630692370302 % random_state 752
# r2_score -3.1821364676541286 % random_state 753
# r2_score 39.41838773910572 % random_state 754
# r2_score -267.108224349147 % random_state 755
# r2_score -35.45661722530342 % random_state 756
# r2_score 64.26866551808885 % random_state 757
# r2_score -142.23549869094438 % random_state 758
# r2_score 39.73035126965503 % random_state 759
# r2_score 62.683484241130415 % random_state 760
# r2_score 35.983068122919306 % random_state 761
# r2_score 56.1329678610879 % random_state 762
# r2_score 29.822808628008225 % random_state 763
# r2_score 10.730251932039259 % random_state 764
# r2_score 30.39915223760484 % random_state 765
# r2_score 68.99545540456049 % random_state 766
# r2_score -10.39254919455017 % random_state 767
# r2_score -20.754180757360462 % random_state 768
# r2_score 56.88458504861003 % random_state 769
# r2_score 6.835328044091016 % random_state 770
# r2_score 22.127149079925402 % random_state 771
# r2_score 43.44413528625862 % random_state 772
# r2_score 38.970742863518126 % random_state 773
# r2_score 51.03791445776322 % random_state 774
# r2_score -41.8561481829435 % random_state 775
# r2_score 49.57064197209057 % random_state 776
# r2_score 28.89294417265561 % random_state 777
# r2_score -40.776001927012494 % random_state 778
# r2_score 52.457801458449346 % random_state 779
# r2_score -2.201518371684408 % random_state 780
# r2_score 65.65246237830664 % random_state 781
# r2_score 44.90528500281309 % random_state 782
# r2_score -25.61312909253044 % random_state 783
# r2_score 3.2569782834734884 % random_state 784
# r2_score 18.41246808195821 % random_state 785
# r2_score 21.559983234671098 % random_state 786
# r2_score 91.15278606851763 % random_state 787
# r2_score 91.15278606851763 % random_state 787
# r2_score 43.28751603701283 % random_state 788
# r2_score -229.13266093326402 % random_state 789
# r2_score -5.834820902447313 % random_state 790
# r2_score -51.892427487384694 % random_state 791
# r2_score -85.53550463125079 % random_state 792
# r2_score 67.55571364669896 % random_state 793
# r2_score 67.54248150269767 % random_state 794
# r2_score 14.674875733924097 % random_state 795
# r2_score 60.49816391322893 % random_state 796
# r2_score 48.31170900121885 % random_state 797
# r2_score -57.06762561700229 % random_state 798
# r2_score 34.5803103901831 % random_state 799
# r2_score 2.966112134636789 % random_state 800
# r2_score 16.066074211898506 % random_state 801
# r2_score 69.66790000718619 % random_state 802
# r2_score -4.9314975982449605 % random_state 803
# r2_score 67.81830443211891 % random_state 804
# r2_score 51.235506869351696 % random_state 805
# r2_score 33.733913785134206 % random_state 806
# r2_score 52.95609144899078 % random_state 807
# r2_score -45.33040288978118 % random_state 808
# r2_score 58.61968873521084 % random_state 809
# r2_score 67.20511590885914 % random_state 810
# r2_score 63.9157151395479 % random_state 811
# r2_score 93.11951150711735 % random_state 812
# r2_score 93.11951150711735 % random_state 812
# r2_score 70.22273693648798 % random_state 813
# r2_score 40.07918664645382 % random_state 814
# r2_score 46.93528451573524 % random_state 815
# r2_score 35.82059002143281 % random_state 816
# r2_score 55.720028948261444 % random_state 817
# r2_score -3.0129762091827494 % random_state 818
# r2_score 72.5264626519333 % random_state 819
# r2_score 15.612017929431033 % random_state 820
# r2_score -86.38491813142595 % random_state 821
# r2_score 36.167880324851865 % random_state 822
# r2_score 69.86366337232279 % random_state 823
# r2_score -28.054896738176673 % random_state 824
# r2_score 33.46120719484183 % random_state 825
# r2_score 45.64825777533884 % random_state 826
# r2_score 25.153320623674535 % random_state 827
# r2_score 0.38257501777071434 % random_state 828
# r2_score -0.2951071024509311 % random_state 829
# r2_score 27.52536117005543 % random_state 830
# r2_score -0.5418329572404401 % random_state 831
# r2_score 30.449018601219024 % random_state 832
# r2_score 29.31543063094404 % random_state 833
# r2_score 68.22734385463494 % random_state 834
# r2_score 33.32592638332714 % random_state 835
# r2_score 57.54159018630075 % random_state 836
# r2_score -15.431008827938086 % random_state 837
# r2_score 66.57988579432481 % random_state 838
# r2_score 65.03050473647448 % random_state 839
# r2_score -6.685060793448061 % random_state 840
# r2_score 36.792410021201825 % random_state 841
# r2_score 42.88565899968992 % random_state 842
# r2_score 59.19695356946675 % random_state 843
# r2_score 70.69835973336006 % random_state 844
# r2_score -203.56283691668847 % random_state 845
# r2_score 36.75849277662998 % random_state 846
# r2_score -56.01588157145041 % random_state 847
# r2_score 66.89766757246984 % random_state 848
# r2_score -15.678179317472129 % random_state 849
# r2_score 83.09167853106104 % random_state 850
# r2_score 67.25324687578896 % random_state 851
# r2_score -154.97172125015734 % random_state 852
# r2_score 14.581644182991871 % random_state 853
# r2_score 5.130853006832226 % random_state 854
# r2_score 57.50377373075801 % random_state 855
# r2_score 43.065101736743635 % random_state 856
# r2_score 49.606200633734154 % random_state 857
# r2_score 70.7771155748466 % random_state 858
# r2_score -57.933322531438414 % random_state 859
# r2_score 28.95526134534756 % random_state 860
# r2_score 71.62072458382607 % random_state 861
# r2_score -137.93987384462238 % random_state 862
# r2_score 58.68154208854697 % random_state 863
# r2_score 8.244750283561487 % random_state 864
# r2_score 44.55655393760558 % random_state 865
# r2_score -2.00878063955352 % random_state 866
# r2_score -66.34483424563591 % random_state 867
# r2_score 47.65356859337633 % random_state 868
# r2_score 33.99076759232709 % random_state 869
# r2_score 74.19032874287723 % random_state 870
# r2_score 81.59385911675554 % random_state 871
# r2_score 52.13908890949015 % random_state 872
# r2_score -0.7238953109909296 % random_state 873
# r2_score 6.621312406500834 % random_state 874
# r2_score 17.81950636561841 % random_state 875
# r2_score -44.174582043298 % random_state 876
# r2_score -245.41159322927194 % random_state 877
# r2_score 44.878313376666014 % random_state 878
# r2_score -73.44753343337096 % random_state 879
# r2_score 49.700319844795416 % random_state 880
# r2_score 84.42448003801569 % random_state 881
# r2_score -252.75231158915594 % random_state 882
# r2_score -9.000275937043867 % random_state 883
# r2_score 13.961970803259282 % random_state 884
# r2_score 55.8055219060974 % random_state 885
# r2_score 76.36561644731415 % random_state 886
# r2_score -7.385567540067406 % random_state 887
# r2_score 20.925895811623164 % random_state 888
# r2_score 68.63477353411156 % random_state 889
# r2_score 68.99199224013533 % random_state 890
# r2_score -7.723822751724452 % random_state 891
# r2_score 72.84361968826006 % random_state 892
# r2_score 59.586933000027365 % random_state 893
# r2_score 10.331147440362088 % random_state 894
# r2_score 68.61480190714511 % random_state 895
# r2_score 37.25043092026904 % random_state 896
# r2_score -7.834072716449603 % random_state 897
# r2_score 67.89414516429753 % random_state 898
# r2_score 45.64496792166031 % random_state 899
# r2_score 13.077929344844573 % random_state 900
# r2_score 4.515085540010633 % random_state 901
# r2_score -39.85490884354035 % random_state 902
# r2_score -50.107191529332674 % random_state 903
# r2_score 50.97285836316278 % random_state 904
# r2_score 71.99789476177332 % random_state 905
# r2_score 43.57404993876657 % random_state 906
# r2_score 39.53246668450055 % random_state 907
# r2_score -148.86172737388748 % random_state 908
# r2_score 34.63082283805329 % random_state 909
# r2_score -47.9336243780802 % random_state 910
# r2_score 9.07643793886156 % random_state 911
# r2_score 29.054057306226245 % random_state 912
# r2_score -1.725767007090817 % random_state 913
# r2_score 56.47269282959548 % random_state 914
# r2_score 6.245284102162952 % random_state 915
# r2_score 7.991187084406737 % random_state 916
# r2_score -84.44318379491335 % random_state 917
# r2_score 54.300620439088654 % random_state 918
# r2_score 66.21166750493492 % random_state 919
# r2_score 41.1909824170956 % random_state 920
# r2_score -61.45922184758268 % random_state 921
# r2_score 34.10136600239927 % random_state 922
# r2_score 88.254308196726 % random_state 923
# r2_score 18.897071379351292 % random_state 924
# r2_score 19.805744959719142 % random_state 925
# r2_score 32.40342539696034 % random_state 926
# r2_score -0.495706871934809 % random_state 927
# r2_score 61.990823952491425 % random_state 928
# r2_score 33.00440709609344 % random_state 929
# r2_score 40.219849395257235 % random_state 930
# r2_score -46.27697288109087 % random_state 931
# r2_score 38.294836335543714 % random_state 932
# r2_score 57.596623914964184 % random_state 933
# r2_score 68.73930035656844 % random_state 934
# r2_score 8.162994810308266 % random_state 935
# r2_score 46.4604578445372 % random_state 936
# r2_score 30.66002225711114 % random_state 937
# r2_score 44.72441742586519 % random_state 938
# r2_score 24.363935007979485 % random_state 939
# r2_score 17.08544691489362 % random_state 940
# r2_score 67.98307380041713 % random_state 941
# r2_score -132.18784358071414 % random_state 942
# r2_score -20.897927696668226 % random_state 943
# r2_score 75.72268987011526 % random_state 944
# r2_score 12.367934333851771 % random_state 945
# r2_score 35.88653201601443 % random_state 946
# r2_score -3.1246331526923576 % random_state 947
# r2_score 79.73766793210679 % random_state 948
# r2_score 86.05646318059293 % random_state 949
# r2_score 39.79378639526322 % random_state 950
# r2_score 45.42458735811004 % random_state 951
# r2_score 29.427383321472544 % random_state 952
# r2_score 76.89512395737326 % random_state 953
# r2_score 52.89022854211727 % random_state 954
# r2_score -13.976095153045964 % random_state 955
# r2_score 19.225152371026166 % random_state 956
# r2_score 46.84050584707603 % random_state 957
# r2_score 35.313848954307204 % random_state 958
# r2_score 56.84179638226298 % random_state 959
# r2_score 29.39815137395797 % random_state 960
# r2_score 67.25940900503686 % random_state 961
# r2_score 40.94149693066679 % random_state 962
# r2_score 43.55242246705318 % random_state 963
# r2_score 57.069597236415994 % random_state 964
# r2_score 53.833134225399384 % random_state 965
# r2_score 51.956347615922404 % random_state 966
# r2_score -0.6357845826052255 % random_state 967
# r2_score 74.29368826559578 % random_state 968
# r2_score 49.59682840217632 % random_state 969
# r2_score 63.069443574137686 % random_state 970
# r2_score 57.396821689089904 % random_state 971
# r2_score -33.260343868966416 % random_state 972
# r2_score -17.744622460555636 % random_state 973
# r2_score -12.609649644278731 % random_state 974
# r2_score 81.46448068149566 % random_state 975
# r2_score 65.81441764142699 % random_state 976
# r2_score 12.109063900607852 % random_state 977
# r2_score 59.76100991297226 % random_state 978
# r2_score -45.24194224923408 % random_state 979
# r2_score 62.13632532794365 % random_state 980
# r2_score -2.234055218620501 % random_state 981
# r2_score 74.22280465841862 % random_state 982
# r2_score 45.411739096631784 % random_state 983
# r2_score 58.47039364153328 % random_state 984
# r2_score 26.945526193012203 % random_state 985
# r2_score 68.61399156771155 % random_state 986
# r2_score 34.74945152410183 % random_state 987
# r2_score 4.456826855417207 % random_state 988
# r2_score -64.0069865801637 % random_state 989
# r2_score -79.14971502955632 % random_state 990
# r2_score 79.34911861233746 % random_state 991
# r2_score -4.3704420789865805 % random_state 992
# r2_score 82.48472949637076 % random_state 993
# r2_score 54.32451683914897 % random_state 994
# r2_score 52.52107597394101 % random_state 995
# r2_score 42.594173472514704 % random_state 996
# r2_score -27.006651148060513 % random_state 997
# r2_score 37.286225978444634 % random_state 998
# r2_score -97.5617864582774 % random_state 999

# %%
print('Best R2 Score is', max_r2_score, 'on Random_state', maxRS)
# Out:
# Best R2 Score is 0.9311951150711736 on Random_state 812

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size = 0.25, random_state = 384)

# %%
reg = LinearRegression()
reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

# %%
print('Intercept: ', reg.intercept_)
print('Linear Coefficient: ', reg.coef_)
# Out:
# Intercept:  81.83548651789259
# Linear Coefficient:  [ 0.00000000e+00  1.11022302e-15  2.35922393e-15  2.09961315e+00
#  -9.22975528e-01  1.55734466e+00  1.07339941e+00 -9.87050152e-01
#   2.15277509e-01 -4.68757937e+00  7.93378814e-01  3.86065895e-01
#   3.51560350e+00  4.03821046e-02]

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

print('R2 Score: ', r2_score(y_test, y_pred))

print("Mean Absolute Error: ", mean_absolute_error(y_test,y_pred))

print("Mean Squared Error: ", mean_squared_error(y_test,y_pred))

print("Square Root of Mean Square Error: ", np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2 Score:  0.5444128896524401
# Mean Absolute Error:  5.375466898189277
# Mean Squared Error:  34.04801794988092
# Square Root of Mean Square Error:  5.835067947323401

# %% [markdown]
# Since there seems to be some relation between independent variable --> R (Run) and Target Variable --> W (Win), therefore applying Hypothesis Testing to identify whether relation between them exists or not.

# %% [markdown]
# # Hypothesis Testing and P-Values
#
# - Ho = there is no relation between Run and Win.
# - Ha = There exists a relation between Run and Win.

# %%
import statsmodels.formula.api as smf

lm = smf.ols(formula = 'W ~ R', data = data).fit()

lm.pvalues
# Out:
# Intercept    0.188745
# R            0.017488
# dtype: float64

# %% [markdown]
# - now since, the p-value is less than alpha value(i.e. 0.05), we reject the null hypothesis.
# - which means, there exists a relation between the Run and Win.

# %%
lm.rsquared
# Out:
# 0.1855460212759742

# %%
lm = LinearRegression()
lm.fit(x_scaled,y)

print('Intercept: ',lm.intercept_)
print('R: ', lm.coef_[0])
print('AB: ', lm.coef_[1])
print('H: ', lm.coef_[2])
print('Double: ', lm.coef_[3])
print('Triple: ', lm.coef_[4])
print('HR: ', lm.coef_[5])
print('BB: ', lm.coef_[6])
print('SO: ', lm.coef_[7])
print('SB: ', lm.coef_[8])
print('RA: ', lm.coef_[9])
print('CG: ', lm.coef_[10])
print('SHO: ', lm.coef_[11])
print('SV: ', lm.coef_[12])
print('E: ', lm.coef_[13])
# Out:
# Intercept:  80.96666666666667
# R:  0.0
# AB:  0.0
# H:  8.881784197001252e-16
# Double:  1.612399464664409
# Triple:  0.95593227215875
# HR:  3.083803551635833
# BB:  0.6417335300596025
# SO:  -1.313752191270579
# SB:  -0.3724685312289203
# RA:  -5.631441963175685
# CG:  0.6757431082555256
# SHO:  0.5005722272497642
# SV:  3.620629935789827
# E:  1.113929623433805

# %%
lm = smf.ols(formula = 'W ~ R + AB + H + Double + Triple + HR + BB + SO + SB +RA + CG + SHO + SV + E', data = data).fit()

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      W   R-squared:                       0.936
# Model:                            OLS   Adj. R-squared:                  0.876
# Method:                 Least Squares   F-statistic:                     15.64
# Date:                Tue, 01 Aug 2023   Prob (F-statistic):           1.82e-06
# Time:                        12:30:18   Log-Likelihood:                -71.258
# No. Observations:                  30   AIC:                             172.5
# Df Residuals:                      15   BIC:                             193.5
# Df Model:                          14
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.1071     79.580      0.077      0.940    -163.514     175.728
# R              0.1459      0.038      3.819      0.002       0.064       0.227
# AB             0.0123      0.020      0.605      0.555      -0.031       0.055
# H             -0.0253      0.035     -0.721      0.482      -0.100       0.049
# Double        -0.1054      0.072     -1.458      0.166      -0.260       0.049
# Triple        -0.0398      0.113     -0.351      0.730      -0.281       0.202
# HR            -0.1056      0.059     -1.785      0.094      -0.232       0.020
# BB            -0.0181      0.023     -0.804      0.434      -0.066       0.030
# SO             0.0090      0.010      0.928      0.368      -0.012       0.030
# SB            -0.0120      0.041     -0.296      0.771      -0.099       0.075
# RA            -0.0680      0.021     -3.189      0.006      -0.114      -0.023
# CG             0.8753      0.408      2.145      0.049       0.005       1.745
# SHO            0.2593      0.305      0.850      0.409      -0.391       0.910
# SV             0.6900      0.153      4.506      0.000       0.364       1.016
# E             -0.0089      0.070     -0.126      0.901      -0.159       0.141
# ==============================================================================
# Omnibus:                        7.233   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.027   Jarque-Bera (JB):                5.532
# Skew:                          -0.843   Prob(JB):                       0.0629
# Kurtosis:                       4.257   Cond. No.                     7.03e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.03e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ##### Observations
#
# 1. P value for R, HR, SV and RA is very low, that means there is a strong relation between these variables and Win.
#
# 2. p value for E is 0.975, which is very high. we can assume that E does not have any significant effect on Win.
#
# 3. R2 and Adj. R2 values are 0.936 and 0.876 respectively, which means the intercept model is very good.

# %%
lm = smf.ols(formula = 'W ~ R+HR+RA+SV', data = data).fit()

lm.rsquared
# Out:
# 0.8971237558371721

# %% [markdown]
# it is clear from R2 values for R, HR, RA and SV have correlation of about 89% with Win.

# %%
lm = smf.ols(formula = 'W ~ AB+E', data = data).fit()

lm.rsquared
# Out:
# 0.011956169381316939

# %% [markdown]
# As observed above, AB and E does dont have any significant effect on win as they have only 1.1% correlation with Win.

# %%
lm = smf.ols(formula = 'W ~  H + Double + Triple + BB + SO + SB + CG + SHO', data = data).fit()

lm.rsquared
# Out:
# 0.5489667438363385

# %% [markdown]
# All other data Points are only 54.8% correlated with Win.

# %%
def print_score(clf, x_train, x_test, y_train, y_test, train=True):
    if train:
        y_pred = clf.predict(x_train)
        
        print("\n====================Train Result======================")
        
        print(f"R2 Score: {r2_score(y_train, y_pred)}")
        
    elif train==False:
        pred = clf.predict(x_test)
        
        print("\n====================Test Result======================")
        
        print(f"R2 Score: {r2_score(y_test, pred)}")
        
        print(f"Root Mean Square Error : {np.sqrt(mean_squared_error(y_test,pred))} ")

# %%
reg = LinearRegression()

# Regression Model training and printing train and test score
reg.fit(x_train, y_train)

# call the function and pass dataset to check train and test score
print_score(reg, x_train, x_test, y_train, y_test, train=True)

print_score(reg, x_train, x_test, y_train, y_test, train=False)
# Out:
# ====================Train Result======================
# R2 Score: 0.8769775754362715
#
# ====================Test Result======================
# R2 Score: 0.5444128896524401
# Root Mean Square Error : 5.835067947323401

# %%
from sklearn.svm import SVC

svc = SVC()

# SVC Model training and printing train and test score
svc.fit(x_train, y_train)

# call the function and pass dataset to check train and test score
print_score(svc, x_train, x_test, y_train, y_test, train=True)

print_score(svc, x_train, x_test, y_train, y_test, train=False)
# Out:
# ====================Train Result======================
# R2 Score: 0.8871014703741447
#
# ====================Test Result======================
# R2 Score: -1.4403094292285177
# Root Mean Square Error : 13.504628836069505

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()

# RandomForestClassifier Model training and printing train and test score
rf.fit(x_train, y_train)

# call the function and pass dataset to check train and test score
print_score(rf, x_train, x_test, y_train, y_test, train=True)

print_score(rf, x_train, x_test, y_train, y_test, train=False)
# Out:
# ====================Train Result======================
# R2 Score: 0.9360615591789198
#
# ====================Test Result======================
# R2 Score: 0.2957402467070872
# Root Mean Square Error : 7.254819949523215

# %%
import xgboost as xgb
xgb = xgb.XGBRegressor()

# XGBoost Regressor Model training and printing train and test score
xgb.fit(x_train, y_train)

# call the function and pass dataset to check train and test score
print_score(xgb, x_train, x_test, y_train, y_test, train=True)

print_score(xgb, x_train, x_test, y_train, y_test, train=False)
# Out:
# ====================Train Result======================
# R2 Score: 0.9999999970279948
#
# ====================Test Result======================
# R2 Score: 0.1023958987431196
# Root Mean Square Error : 8.190352953619866

# %%
from sklearn.neighbors import KNeighborsRegressor

knn = KNeighborsRegressor()

# KNN Regressor Model training and printing train and test score
knn.fit(x_train, y_train)

# call the function and pass dataset to check train and test score
print_score(knn, x_train, x_test, y_train, y_test, train=True)

print_score(knn, x_train, x_test, y_train, y_test, train=False)
# Out:
# ====================Train Result======================
# R2 Score: 0.6698879021691659
#
# ====================Test Result======================
# R2 Score: 0.22987246498013814
# Root Mean Square Error : 7.586501169841075

# %% [markdown]
# ###### Amongst the ML Models, Linear Regression has the best R2 score. Therefore, Let's perform Cross validation(Ridge and Lasso) and Parameter Tuning(Model Regularization using Ridge and Lasso) on Linear Regression Model.

# %% [markdown]
# # Model Regularization Method

# %%
from sklearn.linear_model import Ridge, Lasso, RidgeCV, LassoCV

# %%
lasscv = LassoCV(alphas = None, max_iter = 100, normalize = True)
lasscv.fit(x_train, y_train)
# Out:
# LassoCV(max_iter=100, normalize=True)

# %%
alpha = lasscv.alpha_

alpha
# Out:
# 0.17790042033836612

# %%
lasso_reg = Lasso(alpha)

lasso_reg.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.17790042033836612)

# %%
lasso_reg.score(x_test,y_test)
# Out:
# 0.5772835481190254

# %% [markdown]
# # Ridge CV

# %%
ridgecv = RidgeCV(alphas = np.arange(0.001,2,0.01), normalize = True)

ridgecv.fit(x_train,y_train)
# Out:
# RidgeCV(alphas=array([1.000e-03, 1.100e-02, 2.100e-02, 3.100e-02, 4.100e-02, 5.100e-02,
#        6.100e-02, 7.100e-02, 8.100e-02, 9.100e-02, 1.010e-01, 1.110e-01,
#        1.210e-01, 1.310e-01, 1.410e-01, 1.510e-01, 1.610e-01, 1.710e-01,
#        1.810e-01, 1.910e-01, 2.010e-01, 2.110e-01, 2.210e-01, 2.310e-01,
#        2.410e-01, 2.510e-01, 2.610e-01, 2.710e-01, 2.810e-01, 2.910e-01,
#        3.010e-01, 3.110e-01, 3.210e-0...
#        1.621e+00, 1.631e+00, 1.641e+00, 1.651e+00, 1.661e+00, 1.671e+00,
#        1.681e+00, 1.691e+00, 1.701e+00, 1.711e+00, 1.721e+00, 1.731e+00,
#        1.741e+00, 1.751e+00, 1.761e+00, 1.771e+00, 1.781e+00, 1.791e+00,
#        1.801e+00, 1.811e+00, 1.821e+00, 1.831e+00, 1.841e+00, 1.851e+00,
#        1.861e+00, 1.871e+00, 1.881e+00, 1.891e+00, 1.901e+00, 1.911e+00,
#        1.921e+00, 1.931e+00, 1.941e+00, 1.951e+00, 1.961e+00, 1.971e+00,
#        1.981e+00, 1.991e+00]),
#         normalize=True)

# %%
alpha = ridgecv.alpha_

alpha
# Out:
# 0.34099999999999997

# %%
ridge_model = Ridge(alpha)

ridge_model.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.34099999999999997)

# %%
ridge_model.score(x_test,y_test)
# Out:
# 0.5250567380830538
